# %%
import glob
import rasterio
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from rasterio.mask import mask
from rasterio.plot import show
import gdal, ogr, os , osr
from skimage import exposure

# Importing machine learning tools for splitting, training, testing and classifying our data
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
def cleaner(rastername):
    raster_array1= rasterio.open(rastername).read(1)*0.0001
    raster_array = raster_array1[2000:5000,1000:6000]
    better_array = np.where((raster_array<1)&(raster_array>0), raster_array, np.nan)
    greenmod = pd.DataFrame(better_array)
    greenmod = greenmod.replace(-0.9999, np.nan)
    cleaned_array = np.array(greenmod)
    return cleaned_array

# %%
def array2raster(rasterfn,newRasterfn,array):
    raster = gdal.Open(rasterfn)
    geotransform = raster.GetGeoTransform()
    originX = geotransform[0]
    originY = geotransform[3]
    pixelWidth = geotransform[1]
    pixelHeight = geotransform[5]
    cols = raster.RasterXSize
    rows = raster.RasterYSize
    driver = gdal.GetDriverByName("GTiff")
    outRaster = driver.Create(newRasterfn, cols, rows, 1, gdal.GDT_Float32)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    outband = outRaster.GetRasterBand(1)
    outband.WriteArray(array)
    outRasterSRS = osr.SpatialReference()
    outRasterSRS.ImportFromWkt(raster.GetProjectionRef())
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()

# %%
Imgfiles = glob.glob('/home/emmanuel/Desktop/BIg data Summer schoo/Landsat8/*band*tif')

# %%
rootdir = '/media/emmanuel/Transcend/L8_Unziped'  # Directory in which all our rasters are stored
dateblue = 4
dategreen = 90
datered = 76
datenir = 92
dateswir = 82
for subdir, dirs, files in os.walk(rootdir):  # For loop that finds rasters according to the band
    for file in files:
        if file.endswith('band2.tif'): #
            dateblue =  int(file[17:25])
            blue = os.path.join(subdir,file)
            bluefile = file
        if file.endswith('band3.tif'):
            dategreen = int(file[17:25])
            green = os.path.join(subdir,file)
        if file.endswith('band4.tif'):
            datered = int(file[17:25])
            red = os.path.join(subdir, file)
        if file.endswith('band5.tif'):
            datenir = int(file[17:25]) 
            nir = os.path.join(subdir, file)
        if file.endswith('band6.tif'):
            dateswir = int(file[17:25])
            swir = os.path.join(subdir, file)
        if dateblue == dategreen  and dategreen == datered and datered == datenir and datenir == dateswir:
            print(dateblue, dategreen, datered, datenir, dateswir)
            try:
                bluemod = cleaner(blue)
                greenmod = cleaner(green)
                redmod = cleaner(red)
                nirmod = cleaner(nir)
                swirmod = cleaner(swir)

                print('Here we go')
                array2raster(Imgfiles[0],'NDVI/' + bluefile,bluemod)
                array2raster(Imgfiles[0],'NDVI/' + greenfile,greenmod)
                array2raster(Imgfiles[0],'NDVI/' + redfile,redmod)
                array2raster(Imgfiles[0],'NDVI/' + nirfile,bluemod)
                array2raster(Imgfiles[0],'NDVI/' + swirfile,swirmod)
                print(bluefile)
                print(greenfile)
                print(redfile)

            except:
                pass

            dateblue = 8
            dategreen = 6
            datered = 98
            datenir = 90
            dateswir = 78
# Out:
# 20150717 20150717 20150717 20150717 20150717
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1GT_175083_20150717_20170407_01_T2_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1GT_175083_20150717_20170407_01_T2_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1GT_175083_20150717_20170407_01_T2_sr_band4.tif
# 20130727 20130727 20130727 20130727 20130727
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130727_20170503_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130727_20170503_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130727_20170503_01_T1_sr_band4.tif
# 20130812 20130812 20130812 20130812 20130812
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130812_20170503_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130812_20170503_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20130812_20170503_01_T1_sr_band4.tif
# 20131031 20131031 20131031 20131031 20131031
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131031_20170429_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131031_20170429_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131031_20170429_01_T1_sr_band4.tif
# 20131218 20131218 20131218 20131218 20131218
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131218_20170427_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131218_20170427_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20131218_20170427_01_T1_sr_band4.tif
# 20140103 20140103 20140103 20140103 20140103
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140103_20170427_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140103_20170427_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140103_20170427_01_T1_sr_band4.tif
# 20140308 20140308 20140308 20140308 20140308
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140308_20170425_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140308_20170425_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140308_20170425_01_T1_sr_band4.tif
# 20140409 20140409 20140409 20140409 20140409
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140409_20170424_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140409_20170424_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140409_20170424_01_T1_sr_band4.tif
# 20140425 20140425 20140425 20140425 20140425
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140425_20170423_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140425_20170423_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140425_20170423_01_T1_sr_band4.tif
# 20140612 20140612 20140612 20140612 20140612
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140612_20170422_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140612_20170422_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140612_20170422_01_T1_sr_band4.tif
# 20140628 20140628 20140628 20140628 20140628
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140628_20170421_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140628_20170421_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140628_20170421_01_T1_sr_band4.tif
# 20140714 20140714 20140714 20140714 20140714
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140714_20170421_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140714_20170421_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140714_20170421_01_T1_sr_band4.tif
# 20140916 20140916 20140916 20140916 20140916
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140916_20170419_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140916_20170419_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20140916_20170419_01_T1_sr_band4.tif
# 20141002 20141002 20141002 20141002 20141002
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141002_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141002_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141002_20180526_01_T1_sr_band4.tif
# 20141018 20141018 20141018 20141018 20141018
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141018_20170418_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141018_20170418_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141018_20170418_01_T1_sr_band4.tif
# 20141221 20141221 20141221 20141221 20141221
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141221_20170416_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141221_20170416_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20141221_20170416_01_T1_sr_band4.tif
# 20150106 20150106 20150106 20150106 20150106
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150106_20170415_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150106_20170415_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150106_20170415_01_T1_sr_band4.tif
# 20150122 20150122 20150122 20150122 20150122
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150122_20170413_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150122_20170413_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150122_20170413_01_T1_sr_band4.tif
# 20150327 20150327 20150327 20150327 20150327
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150327_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150327_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150327_20180526_01_T1_sr_band4.tif
# 20150412 20150412 20150412 20150412 20150412
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150412_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150412_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150412_20180526_01_T1_sr_band4.tif
# 20150428 20150428 20150428 20150428 20150428
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150428_20170409_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150428_20170409_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150428_20170409_01_T1_sr_band4.tif
# 20150615 20150615 20150615 20150615 20150615
# Here we go
# 20150701 20150701 20150701 20150701 20150701
# Here we go
# 20150802 20150802 20150802 20150802 20150802
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150802_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150802_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20150802_20180526_01_T1_sr_band4.tif
# 20151005 20151005 20151005 20151005 20151005
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151005_20170403_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151005_20170403_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151005_20170403_01_T1_sr_band4.tif
# 20151021 20151021 20151021 20151021 20151021
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151021_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151021_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151021_20180526_01_T1_sr_band4.tif
# 20151106 20151106 20151106 20151106 20151106
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151106_20170402_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151106_20170402_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151106_20170402_01_T1_sr_band4.tif
# 20151224 20151224 20151224 20151224 20151224
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151224_20180526_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151224_20180526_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20151224_20180526_01_T1_sr_band4.tif
# 20160109 20160109 20160109 20160109 20160109
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160109_20170405_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160109_20170405_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160109_20170405_01_T1_sr_band4.tif
# 20160210 20160210 20160210 20160210 20160210
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160210_20170330_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160210_20170330_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160210_20170330_01_T1_sr_band4.tif
# 20160601 20160601 20160601 20160601 20160601
# Here we go
# 20160703 20160703 20160703 20160703 20160703
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160703_20170323_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160703_20170323_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160703_20170323_01_T1_sr_band4.tif
# 20160804 20160804 20160804 20160804 20160804
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160804_20170322_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160804_20170322_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20160804_20170322_01_T1_sr_band4.tif
# 20161007 20161007 20161007 20161007 20161007
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161007_20170320_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161007_20170320_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161007_20170320_01_T1_sr_band4.tif
# 20161023 20161023 20161023 20161023 20161023
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161023_20170319_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161023_20170319_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161023_20170319_01_T1_sr_band4.tif
# 20161210 20161210 20161210 20161210 20161210
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161210_20170317_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161210_20170317_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20161210_20170317_01_T1_sr_band4.tif
# 20170228 20170228 20170228 20170228 20170228
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170228_20170316_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170228_20170316_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170228_20170316_01_T1_sr_band4.tif
# 20170316 20170316 20170316 20170316 20170316
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170316_20170328_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170316_20170328_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170316_20170328_01_T1_sr_band4.tif
# 20170401 20170401 20170401 20170401 20170401
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170401_20170414_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170401_20170414_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170401_20170414_01_T1_sr_band4.tif
# 20170519 20170519 20170519 20170519 20170519
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170519_20170525_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170519_20170525_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170519_20170525_01_T1_sr_band4.tif
# 20170620 20170620 20170620 20170620 20170620
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170620_20170630_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170620_20170630_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170620_20170630_01_T1_sr_band4.tif
# 20170706 20170706 20170706 20170706 20170706
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170706_20170716_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170706_20170716_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170706_20170716_01_T1_sr_band4.tif
# 20170722 20170722 20170722 20170722 20170722
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170722_20170728_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170722_20170728_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20170722_20170728_01_T1_sr_band4.tif
# 20171127 20171127 20171127 20171127 20171127
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20171127_20171206_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20171127_20171206_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20171127_20171206_01_T1_sr_band4.tif
# 20180114 20180114 20180114 20180114 20180114
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180114_20180120_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180114_20180120_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180114_20180120_01_T1_sr_band4.tif
# 20180215 20180215 20180215 20180215 20180215
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180215_20180222_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180215_20180222_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180215_20180222_01_T1_sr_band4.tif
# 20180420 20180420 20180420 20180420 20180420
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180420_20180502_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180420_20180502_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180420_20180502_01_T1_sr_band4.tif
# 20180506 20180506 20180506 20180506 20180506
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180506_20180517_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180506_20180517_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180506_20180517_01_T1_sr_band4.tif
# 20180709 20180709 20180709 20180709 20180709
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180709_20180717_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180709_20180717_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20180709_20180717_01_T1_sr_band4.tif
# 20181114 20181114 20181114 20181114 20181114
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181114_20181128_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181114_20181128_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181114_20181128_01_T1_sr_band4.tif
# 20181130 20181130 20181130 20181130 20181130
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181130_20181211_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181130_20181211_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181130_20181211_01_T1_sr_band4.tif
# 20181216 20181216 20181216 20181216 20181216
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181216_20181227_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181216_20181227_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20181216_20181227_01_T1_sr_band4.tif
# 20190218 20190218 20190218 20190218 20190218
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190218_20190222_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190218_20190222_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190218_20190222_01_T1_sr_band4.tif
# 20190306 20190306 20190306 20190306 20190306
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190306_20190309_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190306_20190309_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190306_20190309_01_T1_sr_band4.tif
# 20190407 20190407 20190407 20190407 20190407
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190407_20190422_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190407_20190422_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190407_20190422_01_T1_sr_band4.tif
# 20190813 20190813 20190813 20190813 20190813
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190813_20190820_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190813_20190820_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190813_20190820_01_T1_sr_band4.tif
# 20190829 20190829 20190829 20190829 20190829
# Here we go
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190829_20190903_01_T1_sr_band2.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190829_20190903_01_T1_sr_band3.tif
# /media/emmanuel/Transcend/L8_Unziped/LC08_L1TP_175083_20190829_20190903_01_T1_sr_band4.tif
